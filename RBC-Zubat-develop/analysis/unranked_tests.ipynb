# %%
import math
# %load_ext autoreload
# %autoreload 2

# %%
import csv
import re
import pandas as pd
import numpy as np

import pandas
import os

from reconchess import GameHistory
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ### Load games

# %%
data_path = "../game_logs/unranked_games"
reg = r"u([0-9])r([0-9])"

# %%
from reconchess import WinReason
from dataclasses import dataclass

BOT_NAME = "Zubat"

@dataclass
class GameData:
    opponent: str
    color: bool
    result: int
    reason: WinReason
    moves: int
    
    @classmethod
    def from_file(cls, file: str):
        return cls.from_hist(GameHistory.from_file(file))
    
    @staticmethod
    def from_hist(game_hist: GameHistory):
        return GameData(
            color=(color := game_hist.get_white_player_name() == BOT_NAME),
            result=(
                0 if game_hist.get_winner_color() is None else 
                1 if game_hist.get_winner_color() == color else 
                -1
            ),
            opponent=game_hist.get_black_player_name() if color else game_hist.get_white_player_name(),
            reason=game_hist.get_win_reason(),
            moves=game_hist.num_turns()
        )

# %%
dirs = [re.match(reg, s) for s in os.listdir(data_path)]
dirs = [dir for dir in dirs if dir is not None]
dirs
# Out:
# [<re.Match object; span=(0, 4), match='u0r0'>,
#  <re.Match object; span=(0, 4), match='u0r1'>,
#  <re.Match object; span=(0, 4), match='u0r2'>,
#  <re.Match object; span=(0, 4), match='u0r3'>,
#  <re.Match object; span=(0, 4), match='u0r4'>,
#  <re.Match object; span=(0, 4), match='u1r0'>,
#  <re.Match object; span=(0, 4), match='u1r1'>,
#  <re.Match object; span=(0, 4), match='u1r2'>,
#  <re.Match object; span=(0, 4), match='u1r3'>,
#  <re.Match object; span=(0, 4), match='u1r4'>,
#  <re.Match object; span=(0, 4), match='u2r0'>,
#  <re.Match object; span=(0, 4), match='u2r1'>,
#  <re.Match object; span=(0, 4), match='u2r2'>,
#  <re.Match object; span=(0, 4), match='u2r3'>,
#  <re.Match object; span=(0, 4), match='u2r4'>,
#  <re.Match object; span=(0, 4), match='u3r0'>,
#  <re.Match object; span=(0, 4), match='u3r1'>,
#  <re.Match object; span=(0, 4), match='u3r2'>,
#  <re.Match object; span=(0, 4), match='u3r3'>,
#  <re.Match object; span=(0, 4), match='u3r4'>,
#  <re.Match object; span=(0, 4), match='u4r0'>,
#  <re.Match object; span=(0, 4), match='u4r1'>,
#  <re.Match object; span=(0, 4), match='u4r2'>,
#  <re.Match object; span=(0, 4), match='u4r3'>,
#  <re.Match object; span=(0, 4), match='u4r4'>,
#  <re.Match object; span=(0, 4), match='u5r0'>,
#  <re.Match object; span=(0, 4), match='u5r1'>,
#  <re.Match object; span=(0, 4), match='u5r2'>,
#  <re.Match object; span=(0, 4), match='u5r3'>,
#  <re.Match object; span=(0, 4), match='u5r4'>,
#  <re.Match object; span=(0, 4), match='u6r0'>,
#  <re.Match object; span=(0, 4), match='u6r1'>,
#  <re.Match object; span=(0, 4), match='u6r2'>,
#  <re.Match object; span=(0, 4), match='u6r3'>,
#  <re.Match object; span=(0, 4), match='u6r4'>]

# %%
from collections import defaultdict

games = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: {})))
for dir in dirs:
    for opp in os.listdir(os.path.join(data_path, dir.string)):
        for game_id in os.listdir(os.path.join(data_path, dir.string, opp)):
            try:
                data = GameData.from_file(os.path.join(data_path, dir.string, opp, game_id, f"game_{game_id}.log"))
                games[opp][int(dir.groups()[0])][int(dir.groups()[1])][game_id] = data
                print(data)
            except:
                print(f'{os.path.join(data_path, dir.string, opp, game_id, f"game_{game_id}.log")} NOT FOUND')
# Out:
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=74)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=60)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=89)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=33)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=88)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=104)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=78)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=22)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=30)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=0)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=102)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=78)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=36)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=86)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=126)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=66)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=36)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=68)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=75)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=68)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=68)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=116)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=49)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=39)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=146)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=87)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=30)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=78)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=107)
# GameData(opponent='Oracle', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=228)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=42)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=97)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=51)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=87)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=99)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=66)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=70)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=97)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=126)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=68)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=52)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=117)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=194)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=114)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=75)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=82)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=114)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=87)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=130)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=143)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=100)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=150)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=74)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=97)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=177)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=177)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=118)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=105)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=64)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=85)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=125)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=54)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=115)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=77)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=102)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=110)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=184)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=70)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=49)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=151)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=109)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=121)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=175)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=38)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=47)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=216)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=41)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=194)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=27)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=129)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=234)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=243)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=98)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=97)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=77)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=129)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=228)
# ../game_logs/unranked_games\u0r0\StrangeFish2\733270\game_733270.log NOT FOUND
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=66)
# GameData(opponent='Oracle', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=145)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=65)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=88)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=132)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=90)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=109)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=74)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=73)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=146)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=60)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=106)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=55)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=90)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=72)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=47)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=80)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=65)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=98)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=65)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=54)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=78)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=80)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=94)
# GameData(opponent='Oracle', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=168)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=100)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=115)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=50)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='Oracle', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=276)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=58)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=246)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=92)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=72)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=66)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=72)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=89)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=49)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=115)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=66)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=50)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=93)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=222)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=121)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=84)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=98)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=128)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=131)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=50)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=62)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=77)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=166)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=38)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=113)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=130)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=108)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=134)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=43)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=78)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=83)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=207)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=168)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=162)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=51)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=86)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=115)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=114)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=226)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=107)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=248)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=171)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=112)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=62)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=83)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=107)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=56)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=62)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=99)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=180)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=87)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=133)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=112)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=218)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=75)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=32)
# ../game_logs/unranked_games\u0r2\Oracle\733758\game_733758.log NOT FOUND
# ../game_logs/unranked_games\u0r2\Oracle\733816\game_733816.log NOT FOUND
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=55)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=121)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=47)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=52)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=84)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=80)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=67)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=68)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=64)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=38)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=95)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=73)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=95)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=56)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=84)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=42)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=47)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=52)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=28)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=184)
# ../game_logs/unranked_games\u0r2\Oracle\734001\game_734001.log NOT FOUND
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=86)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=78)
# ../game_logs/unranked_games\u0r2\Oracle\734019\game_734019.log NOT FOUND
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=56)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=67)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=101)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=68)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=82)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=88)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=56)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=104)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=78)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=60)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=12)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=162)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=52)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=55)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=72)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=152)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=99)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=107)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=162)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=123)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=92)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=122)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=94)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=141)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=47)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=39)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=74)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=33)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=74)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=73)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=94)
# GameData(opponent='StrangeFish2', color=True, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=200)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=85)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=118)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=84)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=135)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=70)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=84)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=49)
# GameData(opponent='StrangeFish2', color=True, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=225)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=85)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=62)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=189)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=158)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=48)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=135)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=67)
# ../game_logs/unranked_games\u0r2\StrangeFish2\733757\game_733757.log NOT FOUND
# ../game_logs/unranked_games\u0r2\StrangeFish2\733815\game_733815.log NOT FOUND
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=103)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=108)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=116)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=77)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=118)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=291)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=251)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=80)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=173)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=116)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=77)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=103)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.TIMEOUT: 2>, moves=49)
# ../game_logs/unranked_games\u0r2\StrangeFish2\734011\game_734011.log NOT FOUND
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=95)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=92)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=124)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=100)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=33)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=75)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=90)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=85)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=38)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=83)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=58)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=88)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='Oracle', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=295)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=50)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=49)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=92)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=148)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=48)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=100)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=83)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=62)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=103)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=144)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=64)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=102)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=58)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=16)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=66)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=72)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=41)
# ../game_logs/unranked_games\u0r3\Oracle\734479\game_734479.log NOT FOUND
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=67)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=60)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=91)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=94)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=55)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=68)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=108)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=88)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=31)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=73)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=45)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=64)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=105)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=55)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=111)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=130)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=114)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=101)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=112)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# ../game_logs/unranked_games\u0r3\StrangeFish2\734084\game_734084.log NOT FOUND
# ../game_logs/unranked_games\u0r3\StrangeFish2\734094\game_734094.log NOT FOUND
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=95)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=0)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=58)
# ../game_logs/unranked_games\u0r3\StrangeFish2\734117\game_734117.log NOT FOUND
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=93)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=111)
# ../game_logs/unranked_games\u0r3\StrangeFish2\734144\game_734144.log NOT FOUND
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=49)
# ../game_logs/unranked_games\u0r3\StrangeFish2\734154\game_734154.log NOT FOUND
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=100)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=65)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.TIMEOUT: 2>, moves=35)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=38)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=67)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=167)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=101)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=302)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=113)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=91)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=96)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=60)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=149)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=191)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=73)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=67)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# ../game_logs/unranked_games\u0r3\StrangeFish2\734474\game_734474.log NOT FOUND
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=110)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=106)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=44)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=89)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=51)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=159)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=125)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=65)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=227)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=67)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=116)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=128)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=84)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=72)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=98)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=88)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=87)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=70)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=222)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=73)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=56)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=168)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=50)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=174)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=68)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=82)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=103)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=130)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=28)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=182)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=70)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=32)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=47)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=37)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=58)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=128)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=98)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=107)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=75)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=47)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=36)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=31)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=92)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=100)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=119)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=93)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=72)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=41)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=68)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=77)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=66)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=39)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=132)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=65)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=46)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=133)
# GameData(opponent='StrangeFish2', color=True, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=164)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=120)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=84)
# GameData(opponent='StrangeFish2', color=True, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=172)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=85)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=89)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=97)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=58)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=120)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=103)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=87)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=83)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=89)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=49)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=49)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=132)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=68)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=64)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=67)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=77)
# ...
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=127)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=75)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=57)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=65)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=48)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=80)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=148)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=118)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=82)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=135)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=127)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=82)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=89)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=156)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=55)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=84)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=75)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=126)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=101)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=58)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=47)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=75)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=51)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=49)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=106)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=107)
# GameData(opponent='StrangeFish2', color=True, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=184)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=83)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.TIMEOUT: 2>, moves=186)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=56)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=48)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=176)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=70)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=128)
# GameData(opponent='StrangeFish2', color=True, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=72)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=85)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=95)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=117)
# GameData(opponent='StrangeFish2', color=True, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=58)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.TIMEOUT: 2>, moves=7)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=119)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=45)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=30)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=46)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=38)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=62)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=196)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=120)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=78)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=111)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=27)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=100)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=133)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=67)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=60)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=50)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=154)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=60)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=21)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=64)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=84)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=128)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=78)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=70)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=66)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=86)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=65)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=136)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=47)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=58)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=86)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=43)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=101)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=74)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=44)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=99)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=94)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=74)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=93)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=76)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=82)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=90)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=64)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=80)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=52)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=62)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=38)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=36)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=64)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=76)
# GameData(opponent='Oracle', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=57)
# GameData(opponent='Oracle', color=False, result=1, reason=<WinReason.TIMEOUT: 2>, moves=96)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=105)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=216)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=61)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=127)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=85)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=75)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=138)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=101)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=93)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=83)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=123)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=103)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=81)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=87)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=90)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=87)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=117)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=63)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=65)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=171)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=109)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=85)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=53)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=98)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=57)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=115)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=109)
# GameData(opponent='StrangeFish2', color=False, result=0, reason=<WinReason.MOVE_LIMIT: 5>, moves=249)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=67)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=69)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=91)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=153)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=74)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=83)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=59)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=71)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=79)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=199)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=95)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=86)
# GameData(opponent='StrangeFish2', color=False, result=1, reason=<WinReason.KING_CAPTURE: 1>, moves=62)
# GameData(opponent='StrangeFish2', color=False, result=-1, reason=<WinReason.KING_CAPTURE: 1>, moves=135)

# %%
opp = "Oracle"

for u in games[opp]:
    for r in games[opp][u]:
        print(f"uncertainty: {int(u)*25:03}, risk: {int(r)*0.125:0.3f} - "
              f"games: {len(games[opp][u][r]):02}  "
              f"wins: {len([g for g in games[opp][u][r].values() if g.result == 1]):02}  "
              f"losses: {len([g for g in games[opp][u][r].values() if g.result == -1]):02}  "
              f"ties: {len([g for g in games[opp][u][r].values() if g.result == 0]):02}")
# Out:
# uncertainty: 000, risk: 0.000 - games: 50  wins: 32  losses: 17  ties: 01
# uncertainty: 000, risk: 0.125 - games: 46  wins: 27  losses: 16  ties: 03
# uncertainty: 000, risk: 0.250 - games: 50  wins: 27  losses: 23  ties: 00
# uncertainty: 000, risk: 0.375 - games: 50  wins: 27  losses: 22  ties: 01
# uncertainty: 000, risk: 0.500 - games: 50  wins: 29  losses: 21  ties: 00
# uncertainty: 025, risk: 0.000 - games: 50  wins: 28  losses: 19  ties: 03
# uncertainty: 025, risk: 0.125 - games: 50  wins: 37  losses: 12  ties: 01
# uncertainty: 025, risk: 0.250 - games: 53  wins: 38  losses: 14  ties: 01
# uncertainty: 025, risk: 0.375 - games: 47  wins: 28  losses: 18  ties: 01
# uncertainty: 025, risk: 0.500 - games: 50  wins: 26  losses: 24  ties: 00
# uncertainty: 050, risk: 0.000 - games: 47  wins: 29  losses: 16  ties: 02
# uncertainty: 050, risk: 0.125 - games: 48  wins: 31  losses: 16  ties: 01
# uncertainty: 050, risk: 0.250 - games: 50  wins: 31  losses: 18  ties: 01
# uncertainty: 050, risk: 0.375 - games: 52  wins: 27  losses: 24  ties: 01
# uncertainty: 050, risk: 0.500 - games: 50  wins: 23  losses: 25  ties: 02
# uncertainty: 075, risk: 0.000 - games: 50  wins: 31  losses: 17  ties: 02
# uncertainty: 075, risk: 0.125 - games: 51  wins: 30  losses: 21  ties: 00
# uncertainty: 075, risk: 0.250 - games: 50  wins: 31  losses: 19  ties: 00
# uncertainty: 075, risk: 0.375 - games: 49  wins: 30  losses: 19  ties: 00
# uncertainty: 075, risk: 0.500 - games: 50  wins: 30  losses: 20  ties: 00
# uncertainty: 100, risk: 0.000 - games: 52  wins: 37  losses: 15  ties: 00
# uncertainty: 100, risk: 0.125 - games: 49  wins: 34  losses: 15  ties: 00
# uncertainty: 100, risk: 0.250 - games: 50  wins: 32  losses: 18  ties: 00
# uncertainty: 100, risk: 0.375 - games: 50  wins: 29  losses: 21  ties: 00
# uncertainty: 100, risk: 0.500 - games: 48  wins: 28  losses: 20  ties: 00
# uncertainty: 125, risk: 0.000 - games: 50  wins: 33  losses: 17  ties: 00
# uncertainty: 125, risk: 0.125 - games: 64  wins: 36  losses: 25  ties: 03
# uncertainty: 125, risk: 0.250 - games: 50  wins: 26  losses: 23  ties: 01
# uncertainty: 125, risk: 0.375 - games: 50  wins: 29  losses: 18  ties: 03
# uncertainty: 125, risk: 0.500 - games: 50  wins: 27  losses: 20  ties: 03
# uncertainty: 150, risk: 0.000 - games: 50  wins: 33  losses: 16  ties: 01
# uncertainty: 150, risk: 0.125 - games: 50  wins: 32  losses: 18  ties: 00
# uncertainty: 150, risk: 0.250 - games: 50  wins: 32  losses: 18  ties: 00
# uncertainty: 150, risk: 0.375 - games: 53  wins: 31  losses: 22  ties: 00
# uncertainty: 150, risk: 0.500 - games: 60  wins: 38  losses: 22  ties: 00

# %%
opps = ["Oracle", "StrangeFish2"]

res = {}
fig, ax = plt.subplots()

ax.set_xticks(np.arange(7) * 25)
# ax.set_ylim([0.5, 0.7])

for opp in opps:
    for u in games[opp]:
        res[int(u) * 25] = (len([g for r in games[opp][u] for g in games[opp][u][r].values() if g.result==1]) / 
                            len([g for r in games[opp][u] for g in games[opp][u][r].values() if g.result!=0]))
        
    ax.plot(res.keys(), res.values(), '-o' if opp == 'Oracle' else '--o', label=opp)

    
ax.set_xlabel("β (uncertainty maximizer score weight)")
ax.set_ylabel("Winrate")
ax.set_title(f"Winrate by β (uncertainty maximizer score weight)")
ax.legend()
    
plt.savefig("imgs/winrate_chart_beta.png")
plt.show()

# %%
opps = ["Oracle", "StrangeFish2"]

res = {}

fig, ax = plt.subplots()

for opp in opps:
    for r in range(5):
        res[int(r) * 0.125] = (len([g for u in games[opp] for g in games[opp][u][r].values() if g.result==1]) / 
                            len([g for u in games[opp] for g in games[opp][u][r].values() if g.result!=0]))
    
    ax.plot(res.keys(), res.values(), '-o' if opp == 'Oracle' else '--o', label=opp)
    
ax.set_xticks(np.arange(5) * 0.125)

ax.set_xlabel("γ (risk score weight)")
ax.set_ylabel("Winrate")
ax.set_title(f"Winrate by γ (risk score weight)")
ax.legend()

plt.savefig("imgs/winrate_chart_gamma.png")
plt.show()

# %%
opp = "Oracle"

fig, ax = plt.subplots()

data = [[0 for _ in range(7)] for _ in range(5)]
for u in games[opp]:
    for r in games[opp][u]:
        data[r][u] = min(100, len(games[opp][u][r]))

ax.matshow(data, cmap='winter')
for (i, j), z in np.ndenumerate(data):
    ax.text(j, i, f"{z:02}", ha='center', va='center', color=("black" if z > 20 else "white"))
    
ax.set_xticklabels([f"{x*25}" for x in range(-1,7)])
ax.set_yticklabels([f"{x*0.125}" for x in range(-1,5)])
ax.xaxis.set_ticks_position("bottom")

ax.set_xlabel("Uncertainty")
ax.set_ylabel("Risk")
ax.set_title("Num Games")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17824\779210786.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([f"{x*25}" for x in range(-1,7)])
# C:\Users\User\AppData\Local\Temp\ipykernel_17824\779210786.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"{x*0.125}" for x in range(-1,5)])

# %%
opp = "StrangeFish2"

fig, ax = plt.subplots()

data = [[0 for _ in range(7)] for _ in range(5)]
for u in games[opp]:
    for r in games[opp][u]:
        data[r][u] = len(games[opp][u][r])

ax.matshow(data, cmap='winter')
for (i, j), z in np.ndenumerate(data):
    ax.text(j, i, f"{z:02}", ha='center', va='center', color=("black" if z > 20 else "white"))
    
ax.set_xticklabels([f"{x*25}" for x in range(-1,7)])
ax.set_yticklabels([f"{x*0.125}" for x in range(-1,5)])
ax.xaxis.set_ticks_position("bottom")

ax.set_xlabel("Uncertainty")
ax.set_ylabel("Risk")
ax.set_title("Num Games")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17824\1697794159.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([f"{x*25}" for x in range(-1,7)])
# C:\Users\User\AppData\Local\Temp\ipykernel_17824\1697794159.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"{x*0.125}" for x in range(-1,5)])

# %%
opp = "Oracle"

fig, ax = plt.subplots(figsize=(12, 6))

data = [[float("nan") for _ in range(7)] for _ in range(5)]
for u in games[opp]:
    for r in games[opp][u]:
        dom = len([g for g in list(games[opp][u][r].values())[:50] if g.result != 0])
        if dom != 0:
            data[r][u] = (len([g for g in list(games[opp][u][r].values())[:50] if g.result == 1]) / dom) if dom != 0 else float('nan')

mat = ax.matshow(data, cmap='winter')
for (i, j), z in np.ndenumerate(data):
    # ax.text(j, i, f"{100*z:02.1f}%" if (not np.isnan(z)) else z, ha='center', va='center', color=("white" if z < 0.55 else "black"))
    ax.text(
        j, i,
        f"{len([g for g in list(games[opp][j][i].values())[:50] if g.result == 1])}-"
        f"{len([g for g in list(games[opp][j][i].values())[:50] if g.result == 0])}-"
        f"{len([g for g in list(games[opp][j][i].values())[:50] if g.result == -1])}", 
        ha='center', va='center', color=("white" if z < 0.55 else "black")
    )
    
ax.set_xticklabels([f"{x*25}" for x in range(-1,7)])
ax.set_yticklabels([f"{x*0.125}" for x in range(-1,5)])
ax.xaxis.set_ticks_position("bottom")

cbar = fig.colorbar(mat)
cbar.set_label("Win rate")


ax.set_xlabel("β (uncertainty maximizer score weight)")
ax.set_ylabel("γ (risk score weight)")
ax.set_title(f"Winrate against {opp}\n (wins-ties-losses)")
plt.savefig("imgs/winrate_chart_oracle.png")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17824\3669383825.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([f"{x*25}" for x in range(-1,7)])
# C:\Users\User\AppData\Local\Temp\ipykernel_17824\3669383825.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"{x*0.125}" for x in range(-1,5)])

# %%
opp = "StrangeFish2"

fig, ax = plt.subplots(figsize=(12, 6))

data = [[float("nan") for _ in range(7)] for _ in range(5)]
for u in games[opp]:
    for r in games[opp][u]:
        dom = len([g for g in list(games[opp][u][r].values())[:50] if g.result != 0])
        if dom != 0:
            data[r][u] = (len([g for g in list(games[opp][u][r].values())[:50] if g.result == 1]) / dom) if dom != 0 else float('nan')

mat = ax.matshow(data, cmap='winter')
for (i, j), z in np.ndenumerate(data):
    # ax.text(j, i, f"{100*z:02.1f}%" if (not np.isnan(z)) else z, ha='center', va='center', color=("white" if z < 0.55 else "black"))
    ax.text(
        j, i,
        f"{len([g for g in list(games[opp][j][i].values())[:50] if g.result == 1])}-"
        f"{len([g for g in list(games[opp][j][i].values())[:50] if g.result == 0])}-"
        f"{len([g for g in list(games[opp][j][i].values())[:50] if g.result == -1])}", 
        ha='center', va='center', color=("white" if z < 0.25 else "black")
    )
    
ax.set_xticklabels([f"{x*25}" for x in range(-1,7)])
ax.set_yticklabels([f"{x*0.125}" for x in range(-1,5)])
ax.xaxis.set_ticks_position("bottom")

cbar = fig.colorbar(mat)
cbar.set_label("Win rate")

ax.set_xlabel("β (uncertainty maximizer score weight)")
ax.set_ylabel("γ (risk score weight)")
ax.set_title(f"Winrate against {opp}\n (wins-ties-losses)")
plt.savefig("imgs/winrate_chart_sf2.png")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17824\2692027854.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([f"{x*25}" for x in range(-1,7)])
# C:\Users\User\AppData\Local\Temp\ipykernel_17824\2692027854.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"{x*0.125}" for x in range(-1,5)])

# %%
data = [1561, 1377, 1543, 1540, 1537, 1549, 1450, 1602, 1647, 1584, 1540, 1560, 1649, 1665]

plt.plot(np.arange(1, 15), data, "-o")
plt.xticks(np.arange(1, 15))
plt.title("Elo results from initial tuning")
plt.xlabel("Configuration")
plt.ylabel("Final elo")

plt.savefig("imgs/tuning_elo.png")
